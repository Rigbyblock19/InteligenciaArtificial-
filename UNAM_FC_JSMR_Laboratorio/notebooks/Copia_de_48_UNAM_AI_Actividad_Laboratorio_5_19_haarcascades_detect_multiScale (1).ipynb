# %% [markdown]
# <center>
#
# $\Huge \textbf{Universidad Nacional Autónoma de México}$
# $\Huge \textbf{Facultad de Ciencias}$
# <p align="center">
#   <img src="https://www.icat.unam.mx/wp-content/uploads/2021/11/Copia-de-LogoUNAM.-Azul.-Fondo-transparente.png" alt="UNAM" width="200"/>
# </p>
#
# <hr style="height:3px; background-color:#0B6E4F; border:none;"/>
#
#
# $\LARGE \textbf{Inteligencia Artificial}$
#
# $\Large \textit{Laboratorio 5.19}$
#
#
# \begin{array}{rl}
# \textbf{Docente:} & Dra. Jessica Sarahi Méndez Rincón \\[6pt]
# \textbf{Alumna:} & Flores Perusquia Ricardo \\[6pt]
# \textbf{Fecha de realización:} & 13/05/2026
# \end{array}
#
# </center>

# %%
# Se instala opencv-python para usar las librerias correspondientes y necesarias.
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
# Se importan las librerías de para capturar, detectar y procesar los rostros de las personas
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# Se carga la imagen con la que se desarrollara la segunda fase en escalas de grises procesando la imagen y realizando la comparación con su respectiva ecualización de histograma.
img = cv2.imread('Julwa.jpg', cv2.IMREAD_GRAYSCALE)
width, height = img.shape

cv2_imshow (img)
x = np.linspace(0,255, num=256, dtype = np.uint8)
y = np.zeros(256)

for w in range (width):
	for h in range (height):
		v=img[w,h]
		y[v] = y[v]+1;
plt.bar(x,y)
plt.show()
# Out:
# <PIL.Image.Image image mode=L size=250x375>

# %%
# En esta parte del código se implementa el detector de rostros, empezando con el guardado en la función faceClassif del despliegue del xml de un clasificador de rostros previamente entrenado con Haar Cascade de OpenCV por parte de GitHub,
# mismo donde se llama a la función "detectMultiScale" introduciendo el factor de escalado de la imagen a un valor de escala original (1.1), ajustando los parámetros de minNeighbors con la frecuencia de reconocimiento de posible rostro para
# ajustar el promedio de rostros vecinos o cercanos, el mínimo y el máximo escalado de tamaño detectado del recuadro identificador de rostros en la imagen  con "minSize" y "maxSize" respectivamente, ajustando las dimensiones de los recuadros.
import cv2
import numpy as np

faceClassif =  cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

faces = faceClassif.detectMultiScale(img,
	scaleFactor=1.1,
	minNeighbors=5,
	minSize=(30,30),
	maxSize=(200,200))

for (x,y,w,h) in faces:
	cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=250x375>

# %%
# Finalmente se usa la variable reservada con haar cascade para la detección de rostros de la líne anterior, utilizando el factor de escala original y el tamaño ajustado para los rostros de la imagen, implementando el código de filtro gaussiano,
# con un bucle sobre todas las caras detectadas en la imagen, se aplica el filtro gaussiano de desenfoque o "blur"  al rectángulo de la cara, agregando una cara borrosa en la imagen original para obtener y mostarel resultado de la imagen final.
faces = faceClassif.detectMultiScale(img, 1.1, 5)
print("Face detected in the image:", len(faces))


for (x, y, w, h) in faces:
   roi = img[y:y+h, x:x+w]


   roi = cv2.GaussianBlur(roi, (15, 15), 30)


   img[y:y+roi.shape[0], x:x+roi.shape[1]] = roi


cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Face detected in the image: 1
# <PIL.Image.Image image mode=L size=250x375>

# %% [markdown]
# #Conclusión

# %% [markdown]
# En este laboratorio se implementó la detección de rostros utilizando el clasificador en cascada Haar Cascade de OpenCV. Primero se cargó una imagen en escala de grises y se visualizó su histograma de intensidades. Luego, con el clasificador preentrenado haarcascade_frontalface_default.xml, se aplicó la función detectMultiScale que busca regiones que probablemente contengan un rostro, ajustando parámetros como el factor de escala, el número de vecinos y los tamaños mínimo y máximo. Finalmente, sobre cada rostro detectado se aplicó un filtro Gaussiano para desenfocarlo. La idea principal es que Haar Cascade permite detectar objetos (rostros, ojos, sonrisas, etc.) de manera rápida y eficiente mediante la evaluación de características similares a wavelets, siendo una técnica clásica pero aún útil en visión por computadora.

# %% [markdown]
# <hr/>
# <footer style="text-align:center; font-size:12px; color:gray;">
# © 2026 UNAM Facultado de Ciencias – Todos los derechos reservados
#
# </footer>
